# %% [markdown]
# <center><img src="images/header.png"></center>
#
# <h1><center>Алгоритмы интеллектуальной обработки больших объемов данных</center></h1>
# <hr>
# <h2><center>SVM, Kernel Trick (практика)</center></h2>

# %% [markdown]
# **Срок сдачи:** 24 апреля 2017, 06:00 <br>
# **Штраф за опоздание:** -2 балла после 06:00 24 апреля, -4 балла после 06:00 1 мая, -6 баллов после 06:00 8 мая
#
# При отправлении ДЗ указывайте фамилию в названии файла<br>
#
# Не забудте создать задание в Slack через /todo.
#
# Используйте данный Ipython Notebook при оформлении домашнего задания.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# %matplotlib inline

plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# # Семинарская часть

# %% [markdown]
# Функция `select_model` принимает на вход обучающую выборку и возвращает модель (машину опорных векторов) с наилучшими параметрами для данной выборки. Эту функцию нужно реализовать.
#
# Подбираемые параметры подели включают в себя:
# - различные функции ядра (линейное, RBF, полиномиальные разных степеней)
# - различные значения константы $C$ ($0, 0.1, 1, 10, 100, 1000, 10000$)
#
# Подбирать параметры необходимо с помощью 10-fold кросс-валидации. Сейчас в качестве заглушки функция всегда возвращает линейный SVC.

# %%
from sklearn.grid_search import GridSearchCV
from sklearn.model_selection import KFold
# Out:
# /home/vs/Programs/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/vs/Programs/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
def select_model(x, y):
    """
    Implement some model selection strategy here:
    seek through different kernels and parameters.

    Use a validation scheme to select the best model
    
    Quality metric: accuracy

    Returns:
        SVM classifier implemented by sklearn SVC class.
    """
    best_accuracy = 0
    best_model = None
    
    kernel = 'linear'

    model = SVC(kernel=kernel)
    print("Trying model {}".format(model))
    
    param_grid = [{"C": [0.1, 1, 10, 100, 1000],
                  "kernel": ["linear", "rbf"]
                 }, {"C": [0.1, 1, 10, 100, 1000],
                  "kernel": ["poly"],
                  "degree": [2],
                 }]
    
    cv = KFold(n_splits=10, shuffle=True, random_state=123)
    grid = GridSearchCV(estimator=model, param_grid=param_grid, verbose=2,
                        n_jobs=-1, scoring="accuracy", cv=cv.get_n_splits(x, y)
                       )
    
    grid.fit(x, y)
    
    accuracy = np.mean(cross_val_score(model, x, y))

    best_model = grid.best_estimator_
    best_accuracy = accuracy
    
    best_model.fit(x, y)
    print("Best model %s, with accuracy %f" % (best_model, best_accuracy))
    return best_model

# %% [markdown]
# Далее две вспомогательные функции, которые отображают данные и разделяющую поверхность

# %%
def plot_data_set(x, y, description=''):
    print("Plotting data set points")
    plt.figure(figsize=(8, 8))

    colors = np.array(['r', 'b'])[y]
    plt.title(description, fontsize='small')
    plt.scatter(x[:, 0], x[:, 1], marker='o', c=colors, s=50)
    
def plot_decision_region(x1_min, x2_min, x1_max, x2_max, clf, n_points=1000):
    print("Plotting decision region")
    x1, x2 = np.meshgrid(np.linspace(x1_min, x1_max, n_points), np.linspace(x2_min, x2_max, n_points))
    z = clf.decision_function(np.c_[x1.ravel(), x2.ravel()]).reshape(x1.shape)

    plt.contour(x1, x2, z, levels=[0.0], linestyles='solid', linewidths=2.0)
    plt.contour(x1, x2, z, levels=[-1.0, 1.0], linestyles='dashed', linewidths=1.0)

# %%
def generate_linear(size=100, k=1.1, b=0.0, nl=0.1):
    print("Generating 'Linearly-separated' data set")

    x = np.random.random((size, 2))
    y = np.zeros(size, dtype=int)
    noise = np.random.randn(size) * nl
    y[x[:, 1] - (k * x[:, 0] + b) > noise] = 1

    return x, y

x, y = generate_linear()
clf = select_model(x, y)
plot_data_set(x, y)
plot_decision_region(x[:, 0].min(), x[:, 1].min(), x[:, 0].max(), x[:, 1].max(), clf)
# Out:
# Generating 'Linearly-separated' data set
# Trying model SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    1.0s finished
# Best model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False), with accuracy 0.879085
# Plotting data set points
# Plotting decision region

# %%
def generate_concentric(size=100, r1=1.0, r2=2.0, sigma=0.3):
    print("Generating 'Concentric circles' data set")
    x = np.zeros((size, 2))
    print(x.dtype)
    x[:size//2, 0] = sigma * np.random.randn(size//2) + r1
    x[size//2:, 0] = sigma * np.random.randn(size//2) + r2
    x[:, 1] = (np.random.random(size) - 0.5) * 2 * np.pi
    y = np.hstack([np.zeros(size//2, dtype=int), np.ones(size//2, dtype=int)])

    z = np.zeros((size, 2))
    z[:, 0] = x[:, 0] * np.cos(x[:, 1])
    z[:, 1] = x[:, 0] * np.sin(x[:, 1])

    return z, y

x, y = generate_concentric()
clf = select_model(x, y)
plot_data_set(x, y)
plot_decision_region(x[:, 0].min(), x[:, 1].min(), x[:, 0].max(), x[:, 1].max(), clf)
# Out:
# Generating 'Concentric circles' data set
# float64
# Trying model SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:   18.2s finished
# Best model SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=2, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False), with accuracy 0.540441
# Plotting data set points
# Plotting decision region

# %%
def generate_sin(size=200):
    print("Generating 'Sinus-separated' data set")

    x = np.random.random((size, 2))
    x[:, 0] = x[:, 0] * 4 * np.pi
    x[:, 1] = (x[:, 1] - 0.5) * 2
    y = np.zeros(size, dtype=int)
    y[x[:, 1] > np.sin(x[:, 0])] = 1

    return x, y

x, y = generate_sin()
clf = select_model(x, y)
plot_data_set(x, y)
plot_decision_region(x[:, 0].min(), x[:, 1].min(), x[:, 0].max(), x[:, 1].max(), clf)
# Out:
# Generating 'Sinus-separated' data set
# Trying model SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)
# Fitting 10 folds for each of 15 candidates, totalling 150 fits
# [CV] C=0.1, kernel=linear ............................................
# [CV] C=0.1, kernel=linear ............................................
# [CV] ................................... C=0.1, kernel=linear -   0.0s
# [CV] ................................... C=0.1, kernel=linear -   0.0s
# [CV] C=0.1, kernel=linear ............................................
# [CV] C=0.1, kernel=linear ............................................
# [CV] ................................... C=0.1, kernel=linear -   0.0s
# [CV] ................................... C=0.1, kernel=linear -   0.0s
# [CV] C=0.1, kernel=linear ............................................
# [CV] C=0.1, kernel=linear ............................................
# [CV] ................................... C=0.1, kernel=linear -   0.0s
# [CV] ................................... C=0.1, kernel=linear -   0.0s
# [CV] C=0.1, kernel=linear ............................................
# [CV] ................................... C=0.1, kernel=linear -   0.0s
# [CV] C=0.1, kernel=linear ............................................
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] ................................... C=0.1, kernel=linear -   0.0s
# [CV] ...................................... C=0.1, kernel=rbf -   0.0s
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] C=0.1, kernel=linear ............................................
# [CV] ...................................... C=0.1, kernel=rbf -   0.0s
# [CV] ................................... C=0.1, kernel=linear -   0.0s
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] C=0.1, kernel=linear ............................................
# [CV] ...................................... C=0.1, kernel=rbf -   0.0s
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] ................................... C=0.1, kernel=linear -   0.0s
# [CV] ...................................... C=0.1, kernel=rbf -   0.0s
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] ...................................... C=0.1, kernel=rbf -   0.0s
# [CV] ...................................... C=0.1, kernel=rbf -   0.0s
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] ...................................... C=0.1, kernel=rbf -   0.0s
# [CV] ...................................... C=0.1, kernel=rbf -   0.0s
# [CV] C=1, kernel=linear ..............................................
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] ...................................... C=0.1, kernel=rbf -   0.0s
# [CV] C=0.1, kernel=rbf ...............................................
# [CV] ..................................... C=1, kernel=linear -   0.0s
# [CV] C=1, kernel=linear ..............................................
# [CV] ...................................... C=0.1, kernel=rbf -   0.0s
# [CV] C=1, kernel=linear ..............................................
# [CV] ..................................... C=1, kernel=linear -   0.0s
# [CV] ..................................... C=1, kernel=linear -   0.0s
# [CV] C=1, kernel=linear ..............................................
# [CV] C=1, kernel=linear ..............................................
# [CV] ..................................... C=1, kernel=linear -   0.0s
# [CV] ..................................... C=1, kernel=linear -   0.0s
# [CV] C=1, kernel=linear ..............................................
# [CV] C=1, kernel=linear ..............................................
# [CV] ..................................... C=1, kernel=linear -   0.0s
# [CV] ..................................... C=1, kernel=linear -   0.0s
# [CV] C=1, kernel=linear ..............................................
# [CV] C=1, kernel=linear ..............................................
# [CV] ..................................... C=1, kernel=linear -   0.0s
# [CV] ..................................... C=1, kernel=linear -   0.0s
# [CV] C=1, kernel=rbf .................................................
# [CV] C=1, kernel=linear ..............................................
# [CV] ........................................ C=1, kernel=rbf -   0.0s
# [CV] C=1, kernel=rbf .................................................
# [CV] ........................................ C=1, kernel=rbf -   0.0s
# [CV] ..................................... C=1, kernel=linear -   0.0s
# [CV] C=1, kernel=rbf .................................................
# [CV] C=1, kernel=rbf .................................................
# [CV] ........................................ C=1, kernel=rbf -   0.0s
# [CV] C=1, kernel=rbf .................................................
# [CV] ........................................ C=1, kernel=rbf -   0.0s
# [CV] ........................................ C=1, kernel=rbf -   0.0s
# [CV] C=1, kernel=rbf .................................................
# [CV] C=1, kernel=rbf .................................................
# [CV] ........................................ C=1, kernel=rbf -   0.0s
# [CV] ........................................ C=1, kernel=rbf -   0.0s
# [CV] C=10, kernel=linear .............................................
# [CV] C=1, kernel=rbf .................................................
# [CV] ........................................ C=1, kernel=rbf -   0.0s
# [CV] C=1, kernel=rbf .................................................
# [CV] ........................................ C=1, kernel=rbf -   0.0s
# [CV] .................................... C=10, kernel=linear -   0.1s
# [CV] C=1, kernel=rbf .................................................
# [CV] C=10, kernel=linear .............................................
# [CV] ........................................ C=1, kernel=rbf -   0.0s
# [CV] C=10, kernel=linear .............................................
# [CV] .................................... C=10, kernel=linear -   0.1s
# [CV] .................................... C=10, kernel=linear -   0.1s
# [CV] C=10, kernel=linear .............................................
# [CV] C=10, kernel=linear .............................................
# [CV] .................................... C=10, kernel=linear -   0.1s
# [CV] .................................... C=10, kernel=linear -   0.0s
# [CV] C=10, kernel=linear .............................................
# [CV] C=10, kernel=linear .............................................
# [CV] .................................... C=10, kernel=linear -   0.0s
# [CV] C=10, kernel=linear .............................................
# [CV] .................................... C=10, kernel=linear -   0.0s
# [CV] C=10, kernel=linear .............................................
# [CV] .................................... C=10, kernel=linear -   0.0s
# [CV] C=10, kernel=linear .............................................
# [CV] .................................... C=10, kernel=linear -   0.1s
# [CV] C=10, kernel=rbf ................................................
# [CV] ....................................... C=10, kernel=rbf -   0.0s
# [CV] C=10, kernel=rbf ................................................
# [CV] C=10, kernel=rbf ................................................
# [CV] ....................................... C=10, kernel=rbf -   0.0s
# [CV] .................................... C=10, kernel=linear -   0.1s
# [CV] C=10, kernel=rbf ................................................
# [CV] ....................................... C=10, kernel=rbf -   0.0s
# [CV] ....................................... C=10, kernel=rbf -   0.0s
# [CV] C=10, kernel=rbf ................................................
# [CV] C=10, kernel=rbf ................................................
# [CV] ....................................... C=10, kernel=rbf -   0.0s
# [CV] ....................................... C=10, kernel=rbf -   0.0s
# [CV] ....................................... C=10, kernel=rbf -   0.0s
# [CV] C=10, kernel=rbf ................................................
# [CV] C=100, kernel=linear ............................................
# [CV] C=10, kernel=rbf ................................................
# [CV] ....................................... C=10, kernel=rbf -   0.0s
# [CV] C=10, kernel=rbf ................................................
# [CV] ....................................... C=10, kernel=rbf -   0.0s
# [CV] C=10, kernel=rbf ................................................
# [CV] ....................................... C=10, kernel=rbf -   0.0s
# [CV] C=100, kernel=linear ............................................
# [CV] ................................... C=100, kernel=linear -   0.4s
# [CV] C=100, kernel=linear ............................................
# [CV] ................................... C=100, kernel=linear -   0.3s
# [CV] C=100, kernel=linear ............................................
# [CV] ................................... C=100, kernel=linear -   0.3s
# [CV] C=100, kernel=linear ............................................
# [CV] ................................... C=100, kernel=linear -   0.6s
# [CV] C=100, kernel=linear ............................................
# [CV] ................................... C=100, kernel=linear -   0.4s
# [CV] C=100, kernel=linear ............................................
# [CV] ................................... C=100, kernel=linear -   0.3s
# [CV] C=100, kernel=linear ............................................
# [CV] ................................... C=100, kernel=linear -   0.4s
# [CV] C=100, kernel=linear ............................................
# [CV] ................................... C=100, kernel=linear -   0.6s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ...................................... C=100, kernel=rbf -   0.0s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ................................... C=100, kernel=linear -   0.4s
# [CV] C=100, kernel=linear ............................................
# [CV] ...................................... C=100, kernel=rbf -   0.0s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ...................................... C=100, kernel=rbf -   0.0s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ...................................... C=100, kernel=rbf -   0.0s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ...................................... C=100, kernel=rbf -   0.0s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ...................................... C=100, kernel=rbf -   0.0s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ...................................... C=100, kernel=rbf -   0.0s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ...................................... C=100, kernel=rbf -   0.0s
# [CV] C=1000, kernel=linear ...........................................
# [CV] ................................... C=100, kernel=linear -   0.3s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ...................................... C=100, kernel=rbf -   0.0s
# [CV] C=100, kernel=rbf ...............................................
# [CV] ...................................... C=100, kernel=rbf -   0.0s
# [CV] C=1000, kernel=linear ...........................................
# [CV] .................................. C=1000, kernel=linear -   1.5s
# [CV] C=1000, kernel=linear ...........................................
# [CV] .................................. C=1000, kernel=linear -   2.9s
# [CV] C=1000, kernel=linear ...........................................
# [CV] .................................. C=1000, kernel=linear -   2.4s
# [CV] C=1000, kernel=linear ...........................................
# [CV] .................................. C=1000, kernel=linear -   1.6s
# [CV] C=1000, kernel=linear ...........................................
# [CV] .................................. C=1000, kernel=linear -   2.0s
# [CV] C=1000, kernel=linear ...........................................
# [CV] .................................. C=1000, kernel=linear -   2.7s
# [CV] C=1000, kernel=linear ...........................................
# [CV] .................................. C=1000, kernel=linear -   2.2s
# [CV] C=1000, kernel=linear ...........................................
# [CV] .................................. C=1000, kernel=linear -   2.6s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] ..................................... C=1000, kernel=rbf -   0.0s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] ..................................... C=1000, kernel=rbf -   0.0s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] ..................................... C=1000, kernel=rbf -   0.0s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] ..................................... C=1000, kernel=rbf -   0.0s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] ..................................... C=1000, kernel=rbf -   0.0s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] ..................................... C=1000, kernel=rbf -   0.0s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] ..................................... C=1000, kernel=rbf -   0.0s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] ..................................... C=1000, kernel=rbf -   0.0s
# [CV] C=0.1, degree=2, kernel=poly ....................................
# [CV] .................................. C=1000, kernel=linear -   2.3s
# [CV] ........................... C=0.1, degree=2, kernel=poly -   0.0s
# [CV] C=1000, kernel=linear ...........................................
# [CV] C=0.1, degree=2, kernel=poly ....................................
# [CV] ........................... C=0.1, degree=2, kernel=poly -   0.1s
# [CV] C=0.1, degree=2, kernel=poly ....................................
# [CV] ........................... C=0.1, degree=2, kernel=poly -   0.0s
# [CV] C=0.1, degree=2, kernel=poly ....................................
# [CV] ........................... C=0.1, degree=2, kernel=poly -   0.0s
# [CV] C=0.1, degree=2, kernel=poly ....................................
# [CV] ........................... C=0.1, degree=2, kernel=poly -   0.0s
# [CV] C=0.1, degree=2, kernel=poly ....................................
# [CV] ........................... C=0.1, degree=2, kernel=poly -   0.0s
# [CV] C=0.1, degree=2, kernel=poly ....................................
# [CV] ........................... C=0.1, degree=2, kernel=poly -   0.0s
# [CV] C=0.1, degree=2, kernel=poly ....................................
# [CV] ........................... C=0.1, degree=2, kernel=poly -   0.0s
# [CV] C=0.1, degree=2, kernel=poly ....................................
# [CV] ........................... C=0.1, degree=2, kernel=poly -   0.0s
# [CV] C=0.1, degree=2, kernel=poly ....................................
# [CV] ........................... C=0.1, degree=2, kernel=poly -   0.0s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] ............................. C=1, degree=2, kernel=poly -   0.1s
# [CV] C=1, degree=2, kernel=poly ......................................
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed:   15.0s
# [CV] ............................. C=1, degree=2, kernel=poly -   0.5s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] ............................. C=1, degree=2, kernel=poly -   0.2s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] ............................. C=1, degree=2, kernel=poly -   0.2s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] ............................. C=1, degree=2, kernel=poly -   0.1s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] ............................. C=1, degree=2, kernel=poly -   0.1s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] ............................. C=1, degree=2, kernel=poly -   0.2s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] ............................. C=1, degree=2, kernel=poly -   0.4s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] ............................. C=1, degree=2, kernel=poly -   0.1s
# [CV] C=1, degree=2, kernel=poly ......................................
# [CV] ............................. C=1, degree=2, kernel=poly -   0.1s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ............................ C=10, degree=2, kernel=poly -   0.8s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ............................ C=10, degree=2, kernel=poly -   2.2s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ............................ C=10, degree=2, kernel=poly -   1.4s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] .................................. C=1000, kernel=linear -   7.2s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] ..................................... C=1000, kernel=rbf -   0.0s
# [CV] C=1000, kernel=rbf ..............................................
# [CV] ..................................... C=1000, kernel=rbf -   0.0s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ............................ C=10, degree=2, kernel=poly -   1.2s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ............................ C=10, degree=2, kernel=poly -   1.5s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ............................ C=10, degree=2, kernel=poly -   1.0s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ............................ C=10, degree=2, kernel=poly -   1.4s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ............................ C=10, degree=2, kernel=poly -   1.1s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ............................ C=10, degree=2, kernel=poly -   3.1s
# [CV] C=10, degree=2, kernel=poly .....................................
# [CV] ............................ C=10, degree=2, kernel=poly -   1.9s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........................... C=100, degree=2, kernel=poly -  11.5s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........................... C=100, degree=2, kernel=poly -   8.9s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........................... C=100, degree=2, kernel=poly -   9.0s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........................... C=100, degree=2, kernel=poly -  14.2s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........................... C=100, degree=2, kernel=poly -  10.6s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........................... C=100, degree=2, kernel=poly -  12.8s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........................... C=100, degree=2, kernel=poly -  18.8s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........................... C=100, degree=2, kernel=poly -  21.4s
# [CV] C=100, degree=2, kernel=poly ....................................
# [CV] ........................... C=100, degree=2, kernel=poly -  14.0s
# [CV] C=1000, degree=2, kernel=poly ...................................
# [CV] ........................... C=100, degree=2, kernel=poly -  18.8s
# [CV] C=1000, degree=2, kernel=poly ...................................
# [CV] .......................... C=1000, degree=2, kernel=poly - 1.4min
# [CV] C=1000, degree=2, kernel=poly ...................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-c015fbccfd9e> in <module>()
#      11
#      12 x, y = generate_sin()
# ---> 13 clf = select_model(x, y)
#      14 plot_data_set(x, y)
#      15 plot_decision_region(x[:, 0].min(), x[:, 1].min(), x[:, 0].max(), x[:, 1].max(), clf)
#
# <ipython-input-34-ca0b1c80adf1> in select_model(x, y)
#      31                        )
#      32
# ---> 33     grid.fit(x, y)
#      34
#      35     accuracy = np.mean(cross_val_score(model, x, y))
#
# ~/Programs/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py in fit(self, X, y)
#     836
#     837         """
# --> 838         return self._fit(X, y, ParameterGrid(self.param_grid))
#     839
#     840
#
# ~/Programs/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py in _fit(self, X, y, parameter_iterable)
#     572                                     self.fit_params, return_parameters=True,
#     573                                     error_score=self.error_score)
# --> 574                 for parameters in parameter_iterable
#     575                 for train, test in cv)
#     576
#
# ~/Programs/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     787                 # consumption.
#     788                 self._iterating = False
# --> 789             self.retrieve()
#     790             # Make sure that we get a last message telling us we are done
#     791             elapsed_time = time.time() - self._start_time
#
# ~/Programs/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     697             try:
#     698                 if getattr(self._backend, 'supports_timeout', False):
# --> 699                     self._output.extend(job.get(timeout=self.timeout))
#     700                 else:
#     701                     self._output.extend(job.get())
#
# ~/Programs/anaconda3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/Programs/anaconda3/lib/python3.6/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/Programs/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~/Programs/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Регрессия с SVM (3 балла)

# %% [markdown]
# Загрузите набор данных из *titanium.csv*<br/>
# Мы будем решать задачу восстановления столбца 'y' по столбцу 'x'.

# %% [markdown]
# ## Визуализация данных (1 балл)

# %% [markdown]
# Выполните стандартную предобработку данных (z-score) и выведите их на графике.

# %%
import pandas as pd

# %%
df = pd.read_csv("titanium.csv")
df.head()
# Out:
#        x      y
# 0  585.0  0.644
# 1  595.0  0.622
# 2  605.0  0.638
# 3  615.0  0.649
# 4  625.0  0.652

# %%
data = df.values
data -= data.mean(axis=0)
data /= data.std(axis=0)
x = data[:, 0]
y = data[:, 1]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Обучение моделей (2 балла)

# %% [markdown]
# Рассмотрите 3 ядра:
# * Линейное
# * Полиномиальное (degree = 3, gamma = 6, coef0 = 1)
# * RBF (gamma = 6, coef0 = 1)
#
# Во всех случаях установить ширину трубки `epsilon=0.01`
#
# Для каждого из ядер:
# 1. Пусть `C = np.logspace(-2, 2, 10)`. Постройте графики зависимости ошибки от параметра $C$ (ось графика со значениями параметра $C$ должна быть в логарифмической шкале). Ошибка измеряется как средняя абсолютная ошибка.
# 2. Для наулучшего параметра $С$ каждого из ядер постройте график с данными и предстазанием по svm
#
# В каких случаях возникает эффекты недообучения, переобучения?

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.svm import SVR
from tqdm import tqdm

# %%
for params in [{"kernel": "linear"},
               {"kernel": "poly", "degree": 3, "gamma": 6, "coef0": 1},
               {"kernel": "rbf", "gamma": 6, "coef0": 1},
              ]:
    
    errors = []
    c_ = np.logspace(-2, 2, 10)
    
    cv = KFold(n_splits=10, shuffle=True, random_state=123)
    
    best_error = float('+inf')
    
    for c in tqdm(c_):
        model = SVR(C=c, **params)
        
        error = 0
        for train, test in cv.split(x, y):
            x_train, y_train = x[train][:, np.newaxis], y[train]
            model.fit(x_train, y_train)
            x_test, y_test = x[test][:, np.newaxis], y[test]
            y_pred = model.predict(x_test)
            error += mean_absolute_error(y_test, y_pred)
        error /= 10
        
        if error < best_error:
            best_error = error
            best_c = c
        
        errors.append(error)
        
    plt.plot(c_, errors)
    plt.xscale("log")
    plt.title(params["kernel"] + " kernel error")
    plt.xlabel("C")
    plt.ylabel("MAE")
    plt.show()
    
    model = SVR(C=best_c, **params)
    x_test, y_test = x[:, np.newaxis], y
        
    model.fit(x_test, y_test)
    y_pred = model.predict(x_test)
        
    plt.plot(x, y, label="true")
    plt.plot(x_test, y_pred, label="pred")
    plt.title(params["kernel"] + " kernel prediction")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.legend()
    plt.show()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#  50%|█████     | 5/10 [00:00<00:00, 45.72it/s]
#  70%|███████   | 7/10 [00:00<00:00, 32.95it/s]
#  90%|█████████ | 9/10 [00:00<00:00, 20.14it/s]
# 100%|██████████| 10/10 [00:00<00:00, 12.79it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#  30%|███       | 3/10 [00:00<00:00, 21.52it/s]
#  40%|████      | 4/10 [00:00<00:00, 13.73it/s]
#  50%|█████     | 5/10 [00:00<00:00,  7.81it/s]
#  60%|██████    | 6/10 [00:01<00:00,  4.24it/s]
#  70%|███████   | 7/10 [00:03<00:01,  1.93it/s]
#  80%|████████  | 8/10 [00:09<00:02,  1.13s/it]
# Exception in thread Thread-36:
# Traceback (most recent call last):
#   File "/home/vs/Programs/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/home/vs/Programs/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/vs/Programs/anaconda3/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#
# 100%|██████████| 10/10 [01:27<00:00,  8.75s/it]
# 100%|██████████| 10/10 [00:00<00:00, 25.98it/s]

# %% [markdown]
# # Определение языка слова (7 баллов)

# %% [markdown]
# В данном задании вам необходимо определить, на каком языке написано слово.
#
# Вам будет дано два текста - первые предложения произведения "Война и Мир" на английком и испанском, разбитые на слова. У слов нет общепринятого числового представления, поэтому мы предлагаем вам реализовать собственноге ядро для SVM, основанное на редакторском расстоянии или [расстоянии Левинштейна](https://ru.wikipedia.org/wiki/%D0%A0%D0%B0%D1%81%D1%81%D1%82%D0%BE%D1%8F%D0%BD%D0%B8%D0%B5_%D0%9B%D0%B5%D0%B2%D0%B5%D0%BD%D1%88%D1%82%D0%B5%D0%B9%D0%BD%D0%B0).
#
# Имплементировать расстояние Леванштейна не нужно - можно взять любую доступную реализацию, например [здесь](https://github.com/toastdriven/pylev) или [здесь](https://github.com/ztane/python-Levenshtein).

# %% [markdown]
# ## Загрузка (1 балл)
#
# Загрузите данные из файлов *war_and_peace_es.txt* и *war_and_peace_en.txt*.<br/>
# В результате вы должны получить pandas.DataFrame со столбцами *index* | *word* | *label*, где *index* - это индекс pandas, *word* - это слово и *label* - это метка класса (0 или 1)

# %%
df_en = pd.read_csv("war_and_peace_en.txt", header=None)
df_en["label"] = 0
df_es = pd.read_csv("war_and_peace_es.txt", header=None)
df_es["label"] = 1

df = pd.concat([df_en, df_es])

# %%
# like this

df.head()
# Out:
#          0  label
# 0      war      0
# 1      and      0
# 2    peace      0
# 3      leo      0
# 4  tolstoy      0

# %% [markdown]
# ## Подготовка данных (2 балла)
#
# Особенностью пользовательского ядра в sklean.SVC является то, что на вход оно должно принимать именно вектора чисел.<br/>
# В нашем случае это будут индексы соответствующих слов из корпуса. То есть вместо вектора ['treat', 'celebrit', 'prince', ...] на вход в ядро подается вектор из индексов [9209, 11145, 7735, ...] с помощью которых вы будете находить сами слова.
#
# Прежде чем мы начнем строить ядро, надо подготовить данные. Для этого:
# 1. Задайте переменную RND_SEED, которая будет использоваться в любых генераторах случайных чисел в вашем коде (обычно параметр "random_seed")
# 2. Случайным образом перемешайте и заново проиндексируйте таблицу, полученную выше (используйте методы df.sample() и df.reset_index())
# 3. Ядро может вычисляться достаточно долго, поэтому можете урезать таблицу, но оставить в ней не менее 1000 слов.
# 4. Разбейте данные на обучающую и контрольную выборку в пропорции 60/40
#
# В результате вы должны получить вектор-столбец X_train, X_test с **индексами** слов и векторы y_train, y_test с метками классов.

# %%
from sklearn.cross_validation import train_test_split

# %%
corpus = sorted(set(df.loc[:, 0]))
corpus, reverse_corpus = {i: word for i, word in enumerate(corpus)}, {word: i for i, word in enumerate(corpus)}

# %%
df[0] = df[0].replace(reverse_corpus)

# %%
RND_SEED = 123
np.random.seed(RND_SEED)
data = df.values

X, y = data[:, 0:1], data[:, 1]
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.6, random_state=RND_SEED)

# %% [markdown]
# ## Расчет ядра (3 балла)
#
# Некоторые указания по составлению пользовательского ядра можно найти [здесь](http://stackoverflow.com/questions/26962159/how-to-use-a-custom-svm-kernel).
#
# Если в двух словах:<br/>
# Функция, реазлизующая расчет ядра должна принимать две матрицы $U$ и $V$ с признаковым описанием объектов (во време обучения они обе относятся к обучающей выборке, а во время применения - одна матрица относится к обучающей выборке, а другая к контрольной).
#
# В результате, функция должна возвращать матрицу ядра $G_{ij} = K(U_i, V_j)$.
#
# Таким образом, в этом задании вам надо:
# 1. Написать функцию *string_kernel(U, V)*, расчитывающее матрицу ядра $G_{ij}$
# 2. Визуализировать матрицу только для обучающей выборки (функция plt.imshow()).
#
# **ВАЖНО**<br/>
# На лекции мы рассмотрели, что ядро должно обладать определенными свойствами, поэтому не получится рассчитать $G_{ij}$ как расстояние Левинштейна между словами $\text{word}_i$ и $\text{word}_j$.<br/>
# Вместо этого используйте какое-нибудь готовое ядро, зависящее от расстояние между объектами.

# %%
from functools import lru_cache

@lru_cache()
def word_distance(x, y):
    M, N = len(x), len(y)
    D = np.zeros((M, N), dtype=np.int32)
    for j in range(1, N):
        D[0, j] = D[0, j - 1] + 1
    for i in range(1, M):
        D[i, 0] = D[i - 1, 0] + 1
        for j in range(1, N):
            D[i, j] = min([D[i - 1, j] + 1,
                           D[i, j - 1] + 1,
                           D[i - 1, j - 1] + (x[i] != y[j])
                          ])
    return D[M - 1, N - 1]


def word_kernel(U, V):
    U = U[:, 0]
    V = V[:, 0]
    
    result = []
    for word_i in U:
        result.append([])
        for word_j in V:
            result[-1].append(word_distance(corpus[word_i], corpus[word_j]))
    result = np.array(result, dtype=np.float32)
    return np.exp(-result)
            

# G = string_kernel(X_train, X_train)

# %%
plt.imshow(G, cmap='hot')

# %% [markdown]
# ## Оценка качества (1 балл)
#
# Обучите метод опорных векторов с различными значениями параметра штрафа $C$.<br/>
# Для каждого значения выведите accuracy на обучащюей и контрольной выборке.
#
# Постарайтесь достичь качества в 70% на тестовой выборке

# %%
from sklearn.metrics import accuracy_score

# %%
errors = []
c_ = np.logspace(-2, 2, 10)
  
for c in tqdm(c_):
    model = SVC(C=c, kernel=word_kernel)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    error = accuracy_score(y_test, y_pred)
    errors.append(error)

plt.plot(c_, errors)
plt.xscale("log")
plt.title("Accuracy over C")
plt.xlabel("C")
plt.ylabel("Accuracy, %")
plt.show()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-91-f75c23b623a3> in <module>()
#       4 for c in tqdm(c_):
#       5     model = SVC(C=c, kernel=string_kernel)
# ----> 6     model.fit(X_train, y_train)
#       7     y_pred = model.predict(X_test)
#       8
#
# ~/Programs/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     185
#     186         seed = rnd.randint(np.iinfo('i').max)
# --> 187         fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     188         # see comment on the other call to np.iinfo in this file
#     189
#
# ~/Programs/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py in _dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     224             # TODO: add keyword copy to copy on demand
#     225             self.__Xfit = X
# --> 226             X = self._compute_kernel(X)
#     227
#     228             if X.shape[0] != X.shape[1]:
#
# ~/Programs/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py in _compute_kernel(self, X)
#     361             # in the case of precomputed kernel given as a function, we
#     362             # have to compute explicitly the kernel matrix
# --> 363             kernel = self.kernel(X, self.__Xfit)
#     364             if sp.issparse(kernel):
#     365                 kernel = kernel.toarray()
#
# <ipython-input-89-fda7fb1de5c6> in string_kernel(U, V)
#      25         result.append([])
#      26         for word_j in V:
# ---> 27             result[-1].append(word_distance(corpus[word_i], corpus[word_j]))
#      28     result = np.array(result, dtype=np.float32)
#      29     return np.exp(-result)
#
# <ipython-input-89-fda7fb1de5c6> in word_distance(x, y)
#      10         D[i, 0] = D[i - 1, 0] + 1
#      11         for j in range(1, N):
# ---> 12             D[i, j] = min([D[i - 1, j] + 1,
#      13                            D[i, j - 1] + 1,
#      14                            D[i - 1, j - 1] + (x[i] != y[j])
#
# KeyboardInterrupt:
